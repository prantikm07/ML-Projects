# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Files/dogs.csv")
data
# Out:
#      Weight  Height            Class
# 0      42.2      66        Dobermann
# 1      43.0      70        Dobermann
# 2      39.2      67        Dobermann
# 3      49.9      63       Rottweiler
# 4      39.5      65  German Shepherd
# ..      ...     ...              ...
# 295    43.3      67        Dobermann
# 296    52.0      66       Rottweiler
# 297    32.1      61  German Shepherd
# 298    36.8      63  German Shepherd
# 299    57.0      67       Rottweiler
#
# [300 rows x 3 columns]

# %%
data.describe()
# Out:
#            Weight      Height
# count  300.000000  300.000000
# mean    44.258667   65.070000
# std      8.718847    2.794841
# min     27.600000   59.000000
# 25%     37.275000   63.000000
# 50%     43.100000   65.000000
# 75%     53.100000   67.000000
# max     64.200000   72.000000

# %%
class_id = {'Dobermann': 0, 'German Shepherd': 1, 'Rottweiler': 2}
data['Class ID'] = data['Class'].apply(lambda x: class_id[x])
data
# Out:
#      Weight  Height            Class  Class ID
# 0      42.2      66        Dobermann         0
# 1      43.0      70        Dobermann         0
# 2      39.2      67        Dobermann         0
# 3      49.9      63       Rottweiler         2
# 4      39.5      65  German Shepherd         1
# ..      ...     ...              ...       ...
# 295    43.3      67        Dobermann         0
# 296    52.0      66       Rottweiler         2
# 297    32.1      61  German Shepherd         1
# 298    36.8      63  German Shepherd         1
# 299    57.0      67       Rottweiler         2
#
# [300 rows x 4 columns]

# %%
fig, ax = plt.subplots()
ax.scatter(x=data['Weight'], y=data['Height'],c=data['Class ID'])

# %%
model = svm.SVC(kernel='linear')
x = data[['Weight', 'Height']]
y = data['Class ID']
model.fit(x,y)
# Out:
# SVC(kernel='linear')

# %%
x_test = np.random.rand(10000, 2)
x_test = x_test*(45,20) + (25, 55)
y_pred = model.predict(x_test)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
fig, ax = plt.subplots()
ax.scatter(x=x_test[:,0],y=x_test[:,1], c=y_pred, alpha=.5)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x=x_test[:,0],y=x_test[:,1], c=y_pred, alpha=.5)
colors= ['r', 'g', 'b']
ax.scatter(x=data['Weight'], y=data['Height'],c=data['Class ID'].apply(lambda x: colors[x]))
plt.show()
